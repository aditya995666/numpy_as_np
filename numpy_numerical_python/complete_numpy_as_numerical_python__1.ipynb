# %% [markdown]
# ALL MATHMETICAL OPERATION

# %%
import numpy as np

# %%
arr_1d=np.array([1,2,3])
print(arr_1d)
# Out:
# [1 2 3]

# %%
type(arr_1d)
# Out:
# numpy.ndarray

# %%
arr_2d=np.array([[1,2,3],[4,5,6]])
print(arr_2d)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
type(arr_2d)
# Out:
# numpy.ndarray

# %% [markdown]
# DIMENTION OF ARRAY

# %%
arr_2d.ndim
# Out:
# 2

# %% [markdown]
# SHAPE OF ARRAY

# %%
arr_2d.shape
# Out:
# (2, 3)

# %% [markdown]
# SIZE OF ARRAY

# %%
arr_2d.size
# Out:
# 6

# %%
arr_2d.dtype
# Out:
# dtype('int64')
