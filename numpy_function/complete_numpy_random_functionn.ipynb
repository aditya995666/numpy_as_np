# %%
import numpy as np

# %%
import random

# %%
np.random.random(1)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-15adae4bb9f6> in <cell line: 1>()
# ----> 1 np.random.random(3,3)
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.random()
#
# TypeError: random() takes at most 1 positional argument (2 given)
